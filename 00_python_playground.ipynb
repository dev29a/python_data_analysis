# %%
import numpy as np

a= np.array([-1, 1])
b= np.array([1, 1])

print(np.dot(a, b))
# Out:
# 0

# %%
X=np.array([[1,0],[0,1]]) 
Y=np.array([[2,2],[2,2]]) 
Z=np.dot(X,Y)
Z
# Out:
# array([[2, 2],
#        [2, 2]])

# %%
l = [1,2,3,4]
l+[1]
# Out:
# [1, 2, 3, 4, 1]

# %%
data_list = [
    {"name": "Alice", "age": 25, "city": "New York"},
    {"name": "Bob", "age": 30, "city": "Los Angeles"},
    {"name": "Charlie", "age": 35, "city": "Chicago"},
    {"name": "David", "age": 40, "city": None} # Example with a missing value
]

df = pd.DataFrame(data_list)

print(df)

# %%
data = {'emotionPredictions': [{'emotion': {'anger': 0.01364663, 'disgust': 0.0017160787, 'fear': 0.008986978, 'joy': 0.9719017, 'sadness': 0.055187024}, 'target': '', 'emotionMentions': [{'span': {'begin': 0, 'end': 27, 'text': 'I love this new technology.'}, 'emotion': {'anger': 0.01364663, 'disgust': 0.0017160787, 'fear': 0.008986978, 'joy': 0.9719017, 'sadness': 0.055187024}}]}], 'producerId': {'name': 'Ensemble Aggregated Emotion Workflow', 'version': '0.0.1'}}

# %%
print(data)
# Out:
# {'emotionPredictions': [{'emotion': {'anger': 0.01364663, 'disgust': 0.0017160787, 'fear': 0.008986978, 'joy': 0.9719017, 'sadness': 0.055187024}, 'target': '', 'emotionMentions': [{'span': {'begin': 0, 'end': 27, 'text': 'I love this new technology.'}, 'emotion': {'anger': 0.01364663, 'disgust': 0.0017160787, 'fear': 0.008986978, 'joy': 0.9719017, 'sadness': 0.055187024}}]}], 'producerId': {'name': 'Ensemble Aggregated Emotion Workflow', 'version': '0.0.1'}}

# %%
data['emotionPredictions'][0]['emotion']
# Out:
# {'anger': 0.01364663,
#  'disgust': 0.0017160787,
#  'fear': 0.008986978,
#  'joy': 0.9719017,
#  'sadness': 0.055187024,
#  'dominant_emotion': 'joy'}

# %%
max(data['emotionPredictions'][0]['emotion'].values())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 max(data['emotionPredictions'][0]['emotion'].values())
#
# TypeError: '>' not supported between instances of 'str' and 'float'

# %%
print(data['emotionPredictions'][0]['emotion'])
# Out:
# {'anger': 0.01364663, 'disgust': 0.0017160787, 'fear': 0.008986978, 'joy': 0.9719017, 'sadness': 0.055187024, 'dominant_emotion': 'joy'}

# %%
# Out:
# anger 0.01364663
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 6
#       4 for l, s in data['emotionPredictions'][0]['emotion'].items():
#       5     print(l, s)
# ----> 6     if s == max(data['emotionPredictions'][0]['emotion'].values()) :
#       7         d['dominant_emotion'] = l
#
# TypeError: '>' not supported between instances of 'str' and 'float'
