# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv"
df = pd.read_csv(filepath)
df.head(3)
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# 0                9.0       111.0    5000.0       21          27  13495.0
# 1                9.0       111.0    5000.0       21          27  16500.0
# 2                9.0       154.0    5000.0       19          26  16500.0
#
#   city-L/100km  horsepower-binned  diesel  gas
# 0    11.190476             Medium       0    1
# 1    11.190476             Medium       0    1
# 2    12.368421             Medium       0    1
#
# [3 rows x 29 columns]

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %% [markdown]
# ### How could "highway-mpg" help us predict car price?

# %%
X = df[['highway-mpg']]
Y = df['price']

# %%
lm.fit(X, Y)
# Out:
# LinearRegression()

# %%
Yhat=lm.predict(X)
Yhat[0:5]
# Out:
# array([16236.50464347, 16236.50464347, 17058.23802179, 13771.3045085 ,
#        20345.17153508])

# %%
print(lm.intercept_ , lm.coef_)
# Out:
# 38423.3058581574 [-821.73337832]

# %%
lm1 = LinearRegression()

X = df[['engine-size']]
Y = df['price']

lm1.fit(X, Y)
lm1
# Out:
# LinearRegression()

# %%
Yhat = lm1.predict(X)
Yhat[:5]
# Out:
# array([13728.4631336 , 13728.4631336 , 17399.38347881, 10224.40280408,
#        14729.62322775])

# %%
print(lm1.intercept_ ,  lm1.coef_)
# Out:
# -7963.338906281024 [166.86001569]

# %%
Z = df[['horsepower', 'curb-weight','engine-size', 'highway-mpg']]
lm.fit(Z, df['price'])
# Out:
# LinearRegression()

# %%
print(lm.intercept_ ,  lm.coef_)
# Out:
# -15806.62462632923 [53.49574423  4.70770099 81.53026382 36.05748882]

# %%
import seaborn as sns
# %matplotlib inline

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 48169.27392760948)

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(x=df['highway-mpg'], y=df['price'])
plt.show()

# %%
Y_hat = lm.predict(Z)

# %%
plt.figure(figsize=(width, height))


ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()
# Out:
# C:\Users\dev_a\AppData\Local\Temp\ipykernel_7720\4196657742.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
# C:\Users\dev_a\AppData\Local\Temp\ipykernel_7720\4196657742.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)

# %% [markdown]
# # Practice using Car dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score
import warnings
warnings.filterwarnings("ignore", category=UserWarning) 
# %matplotlib inline
path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_mod2.csv"

# %%
df = pd.read_csv(path)
df.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  \
# 0             0           0         Acer         4    2   1         5
# 1             1           1         Dell         3    1   1         3
# 2             2           2         Dell         3    1   1         7
#
#    Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0              14.0       0.551724       8             256          3.528
# 1              15.6       0.689655       4             256          4.851
# 2              15.6       0.931034       8             256          4.851
#
#    Price Price-binned  Screen-Full_HD  Screen-IPS_panel
# 0    978          Low               0                 1
# 1    634          Low               1                 0
# 2    946          Low               1                 0

# %%
lm = LinearRegression()
X = df[['CPU_frequency']]
Y = df['Price']

lm.fit(X, Y)

Yhat = lm.predict(X)
Yhat[:5]
# Out:
# array([1073.07834392, 1277.93263722, 1636.42765051, 1073.07834392,
#        1175.50549057])

# %%
pd.concat([df, pd.DataFrame(Yhat)], axis=1)
# Out:
#      Unnamed: 0.1  Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  \
# 0               0           0         Acer         4    2   1         5
# 1               1           1         Dell         3    1   1         3
# 2               2           2         Dell         3    1   1         7
# 3               3           3         Dell         4    2   1         5
# 4               4           4           HP         4    2   1         7
# ..            ...         ...          ...       ...  ...  ..       ...
# 233           233         233       Lenovo         4    2   1         7
# 234           234         234      Toshiba         3    2   1         5
# 235           235         235       Lenovo         4    2   1         5
# 236           236         236       Lenovo         3    3   1         5
# 237           237         237      Toshiba         3    2   1         5
#
#      Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0                14.0       0.551724       8             256        3.52800
# 1                15.6       0.689655       4             256        4.85100
# 2                15.6       0.931034       8             256        4.85100
# 3                13.3       0.551724       8             128        2.69010
# 4                15.6       0.620690       8             256        4.21155
# ..                ...            ...     ...             ...            ...
# 233              14.0       0.896552       8             256        3.74850
# 234              13.3       0.827586       8             256        2.64600
# 235              12.0       0.896552       8             256        2.99880
# 236              15.6       0.862069       6             256        5.29200
# 237              14.0       0.793103       8             256        4.29975
#
#      Price Price-binned  Screen-Full_HD  Screen-IPS_panel            0
# 0      978          Low               0                 1  1073.078344
# 1      634          Low               1                 0  1277.932637
# 2      946          Low               1                 0  1636.427651
# 3     1244          Low               0                 1  1073.078344
# 4      837          Low               1                 0  1175.505491
# ..     ...          ...             ...               ...          ...
# 233   1891       Medium               0                 1  1585.214077
# 234   1950       Medium               1                 0  1482.786931
# 235   2236       Medium               0                 1  1585.214077
# 236    883          Low               1                 0  1534.000504
# 237   1499          Low               1                 0  1431.573357
#
# [238 rows x 17 columns]

# %%
df = df.rename(columns={'0': 'Y'})

# %%
df.head(2)
# Out:
#    Unnamed: 0.1  Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  \
# 0             0           0         Acer         4    2   1         5
# 1             1           1         Dell         3    1   1         3
#
#    Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0              14.0       0.551724       8             256          3.528
# 1              15.6       0.689655       4             256          4.851
#
#    Price Price-binned  Screen-Full_HD  Screen-IPS_panel
# 0    978          Low               0                 1
# 1    634          Low               1                 0

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(df['Price'], Yhat)
# Out:
# 284583.4405868629

# %%
lm.score(X,Yhat)
# Out:
# 0.1344436321024326

# %%
print(X[:5] , Y[:5], Yhat[:5])
# Out:
#    CPU_frequency
# 0       0.551724
# 1       0.689655
# 2       0.931034
# 3       0.551724
# 4       0.620690 0     978
# 1     634
# 2     946
# 3    1244
# 4     837
# Name: Price, dtype: int64 [1073.07834392 1277.93263722 1636.42765051 1073.07834392 1175.50549057]

# %%
ax1 = sns.displot(df['Price'], hist=False, color='r', label='Actual Value')
sns.distplot(Yhat, hist=False, color="b", label="Fitted Values" , ax=ax1)

plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price')
plt.ylabel('Proportion of laptops')
plt.legend(['Actual Value', 'Predicted Value'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 ax1 = sns.displot(df['Price'], hist=False, color='r', label='Actual Value')
#       2 sns.distplot(Yhat, hist=False, color="b", label="Fitted Values" , ax=ax1)
#       4 plt.title('Actual vs Fitted Values for Price')
#
# File c:\Users\dev_a\Documents\study\GitHub\python_data_analysis\.venv\Lib\site-packages\seaborn\distributions.py:2193, in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2190 if p.univariate:
#    2192     _assign_default_kwargs(hist_kws, p.plot_univariate_histogram, histplot)
# -> 2193     p.plot_univariate_histogram(**hist_kws)
#    2195 else:
#    2197     _assign_default_kwargs(hist_kws, p.plot_bivariate_histogram, histplot)
#
# File c:\Users\dev_a\Documents\study\GitHub\python_data_analysis\.venv\Lib\site-packages\seaborn\distributions.py:571, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     566 if element == "bars":
#     567
#     568     # Use matplotlib bar plotting
#     570     plot_func = ax.bar if self.data_variable == "x" else ax.barh
# --> 571     artists = plot_func(
#     572         hist["edges"],
#     573         hist["heights"] - bottom,
#     574         hist["widths"],
#     575         bottom,
#     576         align="edge",
#     577         **artist_kws,
#     578     )
#     580     for bar in artists:
#     581         if self.data_variable == "x":
#
# File c:\Users\dev_a\Documents\study\GitHub\python_data_analysis\.venv\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File c:\Users\dev_a\Documents\study\GitHub\python_data_analysis\.venv\Lib\site-packages\matplotlib\axes\_axes.py:2654, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2645 for l, b, w, h, c, e, lw, htch, lbl in args:
#    2646     r = mpatches.Rectangle(
#    2647         xy=(l, b), width=w, height=h,
#    2648         facecolor=c,
#    (...)   2652         hatch=htch,
#    2653         )
# -> 2654     r._internal_update(kwargs)
#    2655     r.get_path()._interpolation_steps = 100
#    2656     if orientation == 'vertical':
#
# File c:\Users\dev_a\Documents\study\GitHub\python_data_analysis\.venv\Lib\site-packages\matplotlib\artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File c:\Users\dev_a\Documents\study\GitHub\python_data_analysis\.venv\Lib\site-packages\matplotlib\artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'hist'

# %%
mse_slr = mean_squared_error(df['Price'], Yhat)
r2_score_slr = lm.score(X, Y)
print('The R-square for Linear Regression is: ', r2_score_slr)
print('The mean square error of price and predicted value is: ', mse_slr)
# Out:
# The R-square for Linear Regression is:  0.1344436321024326
# The mean square error of price and predicted value is:  284583.4405868629

# %%
lm1 = LinearRegression()
Z = df[['CPU_frequency','RAM_GB','Storage_GB_SSD','CPU_core','OS','GPU','Category']]
lm1.fit(Z,Y)
Y_hat = lm1.predict(Z)

# %%
ax1 = sns.distplot(df['Price'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)

plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price')
plt.ylabel('Proportion of laptops')
# Out:
# Text(0, 0.5, 'Proportion of laptops')

# %%
ax2 = sns.distplot(df['Price'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax2)

plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price')
plt.ylabel('Proportion of laptops')
# Out:
# Text(0, 0.5, 'Proportion of laptops')
