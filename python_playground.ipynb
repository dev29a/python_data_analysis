# %%
import numpy as np

a= np.array([-1, 1])
b= np.array([1, 1])

print(np.dot(a, b))
# Out:
# 0

# %%
X=np.array([[1,0],[0,1]]) 
Y=np.array([[2,2],[2,2]]) 
Z=np.dot(X,Y)
Z
# Out:
# array([[2, 2],
#        [2, 2]])

# %%
l = [1,2,3,4]
l+[1]
# Out:
# [1, 2, 3, 4, 1]
